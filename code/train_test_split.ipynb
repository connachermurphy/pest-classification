# %% [markdown]
# # train_test_split.ipynb
#
# Create training and test datasets from raw CCMT dataset.
#
# Author: Connacher Murphy

# %%
# Libraries
import numpy as np
import os
from PIL import Image
import shutil

# %%
# Filepaths
path_raw = os.path.expanduser("~/data/ccmt/Raw Data/CCMT Dataset")  # raw data
path_proc = os.path.expanduser("~/data/ccmt_proc")  # destination

# %%
# Set seed for reproducibility
np.random.seed(456)

# Train/test split
split = 0.8

# Crop list
crops = ["Cashew", "Cassava", "Maize", "Tomato"]

# %%
for crop in crops:
    print(f"Sorting images for {crop}")

    if os.path.isdir(os.path.join(path_proc, crop)):
        shutil.rmtree(os.path.join(path_proc, crop))

    os.makedirs(os.path.join(path_proc, crop))
    os.makedirs(os.path.join(path_proc, crop, "train"))
    os.makedirs(os.path.join(path_proc, crop, "test"))

    crop_classes_list = sorted(os.listdir(os.path.join(path_raw, crop)))

    if ".DS_Store" in crop_classes_list:
        crop_classes_list.remove(".DS_Store")

    for crop_class in crop_classes_list:
        os.makedirs(os.path.join(path_proc, crop, "train", crop_class))
        os.makedirs(os.path.join(path_proc, crop, "test", crop_class))

        for roots, dirs, files in os.walk(os.path.join(path_raw, crop, crop_class)):
            for file in files:
                # Check if corrupted
                try:
                    img = Image.open(os.path.join(roots, file))  # open the image file
                    img.load()  # verify that the image is valid
                    img = Image.open(os.path.join(roots, file))  # reopen the image file

                    split_draw = np.random.uniform()

                    if split_draw < split:
                        # img.save(
                        #     os.path.join(path_proc, crop, "train", crop_class, file)
                        # )
                        shutil.copy(
                            os.path.join(roots, file),
                            os.path.join(path_proc, crop, "train", crop_class, file),
                        )
                    else:
                        # img.save(
                        #     os.path.join(path_proc, crop, "test", crop_class, file)
                        # )
                        shutil.copy(
                            os.path.join(roots, file),
                            os.path.join(path_proc, crop, "test", crop_class, file),
                        )

                except (IOError, SyntaxError) as e:
                    print(
                        f"File {file} is corrupted and will not be copied to the processed folder"
                    )
                    continue
    print("\n")
# Out:
# Sorting images for Cashew
#
#
# Sorting images for Cassava
#
#
# Sorting images for Maize
# File healthy88_.jpg is corrupted and will not be copied to the processed folder
# File healthy87_.jpg is corrupted and will not be copied to the processed folder
# File healthy18_.jpg is corrupted and will not be copied to the processed folder
# File healthy189_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle90_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle691_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle326_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle798_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle690_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle68_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle208_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle910_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle458_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle573_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle457_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle206_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle207_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle572_.jpg is corrupted and will not be copied to the processed folder
# File leaf beetle797_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight590_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight379_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight912_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight37_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight98_.jpg is corrupted and will not be copied to the processed folder
# File .DS_Store is corrupted and will not be copied to the processed folder
# File leaf blight82_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight913_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight745_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight522_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight830_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight666_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight667_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight453_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight452_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight746_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight58_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot272_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot881_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot497_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot64_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot496_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot649_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot425_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot798_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot799_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot424_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot957_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot578_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot186_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot958_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot723_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot187_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot353_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot724_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot882_.jpg is corrupted and will not be copied to the processed folder
# File leaf spot271_.jpg is corrupted and will not be copied to the processed folder
# File streak virus422_.jpg is corrupted and will not be copied to the processed folder
# File streak virus998_.jpg is corrupted and will not be copied to the processed folder
# File streak virus486_.jpg is corrupted and will not be copied to the processed folder
# File streak virus701_.jpg is corrupted and will not be copied to the processed folder
# File streak virus485_.jpg is corrupted and will not be copied to the processed folder
# File streak virus997_.jpg is corrupted and will not be copied to the processed folder
# File streak virus554_.jpg is corrupted and will not be copied to the processed folder
# File streak virus626_.jpg is corrupted and will not be copied to the processed folder
# File streak virus627_.jpg is corrupted and will not be copied to the processed folder
# File streak virus774_.jpg is corrupted and will not be copied to the processed folder
# File streak virus421_.jpg is corrupted and will not be copied to the processed folder
# File streak virus118_.jpg is corrupted and will not be copied to the processed folder
# File streak virus773_.jpg is corrupted and will not be copied to the processed folder
# File streak virus119_.jpg is corrupted and will not be copied to the processed folder
#
#
# Sorting images for Tomato
# File healthy76_.jpg is corrupted and will not be copied to the processed folder
# File healthy77_.jpg is corrupted and will not be copied to the processed folder
# File healthy442_.jpg is corrupted and will not be copied to the processed folder
# File healthy443_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight471_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight386_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight997_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight8_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight558_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight470_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight72_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight998_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight1232_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight644_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight645_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight813_.jpg is corrupted and will not be copied to the processed folder
# File leaf blight814_.jpg is corrupted and will not be copied to the processed folder
# File leaf curl43_.jpg is corrupted and will not be copied to the processed folder
# File leaf curl439_.jpg is corrupted and will not be copied to the processed folder
# File leaf curl270_.jpg is corrupted and will not be copied to the processed folder
# File leaf curl354_.jpg is corrupted and will not be copied to the processed folder
# File leaf curl271_.jpg is corrupted and will not be copied to the processed folder
# File leaf curl186_.jpg is corrupted and will not be copied to the processed folder
# File leaf curl353_.jpg is corrupted and will not be copied to the processed folder
# File .DS_Store is corrupted and will not be copied to the processed folder
# File verticillium wilt403_.jpg is corrupted and will not be copied to the processed folder
